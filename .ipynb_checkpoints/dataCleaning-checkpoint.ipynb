# %%
import pandas as pd
import os
import numpy as np
import re
from datetime import datetime
from pymongo import MongoClient

# %%
# def cleanNull(d):
#     clean = {}   
#     for k, v in d.items():
#         if isinstance(v, dict):
#             nested = cleanNull(v)
#             if len(nested.keys()) > 0:
#                 clean[k] = nested
#         elif v is not None:
#             if isinstance(v,list):
#                 v = [v for v in v if str(v) !='nan']
#                 clean[k] = v
#             else:
#                 clean[k] = v   
#     return clean    
def cleanNull(data):
    cleanData = []
    for d in data:
        clean={}
        for k,v in d.items():
            if not(pd.isnull(v)):
                if isinstance(v,str):
                    if re.match('-*[0-9]+([.][0-9]+)?$',v):
                        v = float(v)
                if (k.find(".")!=-1):
                    k = k.replace(".","")
                clean[k] = v
            else:
                pass
        cleanData.append(clean)
    return cleanData

# %%
def connect(airport_name,data):
    cluster = MongoClient("mongodb+srv://dbAAI:maverick123@cluster0-qkpve.mongodb.net/test?retryWrites=true&w=majority")
    db = cluster["AirportDB"]
    collection = db[airport_name]
    collection.insert_one(data)

# %%
def extract(excel):

    ### Loading sheets into DF ###
    df = pd.read_excel(excel,skiprows=[5,9,1], sheet_name=[0,1,2],header=None)
    ### Formatting ###
    t = df[0].loc[3,[1,2]].str.extract('(\d*\s)',expand=False).astype(int)

    ### Formatting strings ###
    for x in range(3):
        df[x].loc[3,[1,2]] = df[x].loc[3,[1,2]].str.extract('(\d*\s)',expand=False).astype(int)
        df[x].loc[6] = df[x].loc[6].str.extract('(\d*\.\d+|\d+)', expand=False).astype(float)  

    ### Extracting numbers from str ###
        for i in range(9,len(df[x]),2):
            df[x].loc[i] = df[x].loc[i].str.extract('(\d*\.\d+|\d+)', expand=False).astype(float) 

#     ### Conversion from str to numeric ###    
#         l = [2,5,6]
#         for i in l:
#             df[x].iloc[i,1:] = pd.to_numeric(df[x].iloc[i,1:], errors = 'coerce',downcast='float')
#         for i in range(8,len(df[x].index)):
#             df[x].iloc[i,1:8] = pd.to_numeric(df[x].iloc[i,1:8], errors = 'coerce',downcast='float')
#             if(x==0):
#                 df[x].iloc[i,8] = pd.to_numeric(df[x].iloc[i,8], errors = 'coerce',downcast='float')      
#         print(type(df[x].iloc[2,8]))

    ### Extracting Date & type ###
    st=df[0].iloc[0,0]
    date = re.findall(r"\d{2}\s\w{3}\s\d{4}",st)
    dates=str(datetime.strptime(date[0],'%d %b %Y').date())
    s = df[0].iloc[1,3]
    types = (re.findall(r"\s\w*\s",s))[0].strip()

    ### airport data ###
    airport = df[0].iloc[1:4,:].copy()
    airport.drop(airport.iloc[:, 4:6], inplace = True, axis = 1) 
    header = airport.iloc[0]
    airport = airport.iloc[1:]
    airport.columns = header
    airport_name = airport.iloc[0,0]

    total_devices = {
        'num': int(airport['Total Devices'].iloc[0]),
        'active': int(airport['Total Devices'].iloc[1])
    }
    active_surveys = {
        'num': int(airport['Active Surveys'].iloc[0]),
        'completed': int(airport['Active Surveys'].iloc[1])
    }

    r = re.compile(".*Rank")
    rank_name = list(filter(r.match, airport.columns))[0] 
    rank = int(airport[rank_name].iloc[0])

    total_resp_till_date = int(airport['Total Responses Till Date'].iloc[0])

    exp_index_till_date = float(airport['Exp. Index Till Date'].iloc[0])

    avg_imp_index = float(airport['Improvement Index'].iloc[0])

    ### all_responses ###
    head = df[0].iloc[4,1:].dropna()
    allResponses = df[0].iloc[5:7,1:].dropna(axis = 1, how = 'all')
    allResponses.columns = head
    allResponses = allResponses.set_index(pd.Index(["resp_no","resp_pct"]))
    allResponses = allResponses.reset_index()
    allResponses.rename(columns={allResponses.columns[0]:'resp'},inplace=True)
    aresp = allResponses.to_dict('record')
    all_resp = cleanNull(aresp)
    
    ### general data input ###
    general = {
            'total_devices': total_devices,
            'active_surveys': active_surveys,
            'rank': rank,
            'total_resp_till_date': total_resp_till_date,
            'avg_exp_index': exp_index_till_date,
            'avg_imp_index': avg_imp_index,
            'all_responses': all_resp
        }

    ### data ###
    data = {
        'date': dates,
        'type': types,
        'general': general
    }

    for i in range(3):
        by_name = (df[i].iloc[7,0]).replace(" ","_").lower()
        bytype = df[i].iloc[8:].dropna(axis = 1, how = 'all')
        col_index = df[i].iloc[7,:].dropna()
        bytype.columns = col_index
        bytype.set_index(df[i].iloc[7,0],inplace = True)
        bytype.index = pd.Series(bytype.index).fillna(method='ffill')
#         byType = bytype.groupby(df[i].iloc[7,0]).agg(lambda x: list(x))
#         byType.columns = df[i].iloc[7,1:].dropna()
#         byType.reset_index(inplace=True)
#         byType.rename(columns={byType.columns[0]:'area'},inplace=True)
#         resp = byType.to_dict('record')
        bytype = bytype.reset_index()
        for x in range(1,len(bytype.index),2):
            bytype.iloc[x,0] = bytype.iloc[x,0] + "_pct"
        bytype.rename(columns={bytype.columns[0]:'area'},inplace=True)
        res = bytype.to_dict('record')
        resp = cleanNull(res)
        
        ### getting top and least areas ###
        air = df[i].iloc[1:4,:]
        header = air.iloc[0]
        air = air.iloc[1:]
        air.columns = header
        top_name = df[i].iloc[1,4]
    #         r = re.compile("Top\s.*")
    #         top_name = list(filter(r.match, air.columns))[0]  
        tnum = float(air[top_name].iloc[0])
        tarea = air[top_name].iloc[1]
        least_name = df[i].iloc[1,5]
    #         r = re.compile("Least")
    #         least_name = list(filter(r.match, air.columns))[0]  
        lnum = float(air[least_name].iloc[0])
        larea = air[least_name].iloc[1]
        top = {
            'exp': tnum,
            'area': tarea
        }
        least = {
            'exp': lnum,
            'area': larea
        }
        airport_name=df[0].iloc[2,0]
        by_type = {
            'top': top,
            'least': least,
            'responses': resp
        }
        data.update({by_name: by_type})
   
    
    ### Connection to database ###
    connect(airport_name,data)
#     print(data)

# %%
arr = os.listdir('./excel')
file = [f for f in arr if f[-3:]=='xls']
for excel in file:
    extract('./excel/'+excel)
# Out:
# {'date': '2020-03-01', 'type': 'EI', 'general': {'total_devices': {'num': 10, 'active': 10}, 'active_surveys': {'num': 6, 'completed': 2}, 'rank': 30, 'total_resp_till_date': 473557, 'avg_exp_index': 42.82, 'avg_imp_index': -11.939649, 'all_responses': [{'resp': 'resp_no', 'Excellent': 374, 'Good': 308, 'Average': 62, 'Poor': 1903, 'Bad': 124, 'Total Responses': 2771, 'Exp Index': 41.4}, {'resp': 'resp_pct', 'Excellent': 13.5, 'Good': 11.12, 'Average': 2.24, 'Poor': 68.68, 'Bad': 4.47}]}, 'by_device': {'top': {'exp': 95.0, 'area': 'Area 1'}, 'least': {'exp': 22.18, 'area': 'Area 9'}, 'responses': [{'area': 'Area 1', 'Excellent': 2, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 2, 'Exp Index': 95.0, 'Improvement Index': 90.0}, {'area': 'Area 1_pct', 'Excellent': 100.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 4', 'Excellent': 96, 'Good': 14, 'Average': 10, 'Poor': 9, 'Bad': 13, 'Total Responses': 142, 'Exp Index': 77.08, 'Improvement Index': -7.21}, {'area': 'Area 4_pct', 'Excellent': 67.61, 'Good': 9.86, 'Average': 7.04, 'Poor': 6.34, 'Bad': 9.15}, {'area': 'Area 2', 'Excellent': 101, 'Good': 228, 'Average': 6, 'Poor': 1, 'Bad': 13, 'Total Responses': 349, 'Exp Index': 75.66, 'Improvement Index': 0.07}, {'area': 'Area 2_pct', 'Excellent': 28.94, 'Good': 65.33, 'Average': 1.72, 'Poor': 0.29, 'Bad': 3.72}, {'area': 'Area 5', 'Excellent': 31, 'Good': 9, 'Average': 4, 'Poor': 5, 'Bad': 10, 'Total Responses': 59, 'Exp Index': 67.51, 'Improvement Index': 17.7}, {'area': 'Area 5_pct', 'Excellent': 52.54, 'Good': 15.25, 'Average': 6.78, 'Poor': 8.47, 'Bad': 16.95}, {'area': 'Area 7', 'Excellent': 18, 'Good': 8, 'Average': 2, 'Poor': 2, 'Bad': 7, 'Total Responses': 37, 'Exp Index': 66.95, 'Improvement Index': 15.42}, {'area': 'Area 7_pct', 'Excellent': 48.65, 'Good': 21.62, 'Average': 5.41, 'Poor': 5.41, 'Bad': 18.92}, {'area': 'Area 3', 'Excellent': 87, 'Good': 34, 'Average': 34, 'Poor': 19, 'Bad': 23, 'Total Responses': 197, 'Exp Index': 66.29, 'Improvement Index': 0.63}, {'area': 'Area 3_pct', 'Excellent': 44.16, 'Good': 17.26, 'Average': 17.26, 'Poor': 9.64, 'Bad': 11.68}, {'area': 'Area 10', 'Excellent': 27, 'Good': 11, 'Average': 3, 'Poor': 4, 'Bad': 15, 'Total Responses': 60, 'Exp Index': 61.57, 'Improvement Index': -8.34}, {'area': 'Area 10_pct', 'Excellent': 45.0, 'Good': 18.33, 'Average': 5.0, 'Poor': 6.67, 'Bad': 25.0}, {'area': 'Area 8', 'Excellent': 5, 'Good': 1, 'Average': 2, 'Poor': 1863, 'Bad': 3, 'Total Responses': 1874, 'Exp Index': 28.19, 'Improvement Index': -0.39}, {'area': 'Area 8_pct', 'Excellent': 0.27, 'Good': 0.05, 'Average': 0.11, 'Poor': 99.41, 'Bad': 0.16}, {'area': 'Area 9', 'Excellent': 7, 'Good': 3, 'Average': 1, 'Poor': 0, 'Bad': 40, 'Total Responses': 51, 'Exp Index': 22.18, 'Improvement Index': 343.53}, {'area': 'Area 9_pct', 'Excellent': 13.73, 'Good': 5.88, 'Average': 1.96, 'Poor': 0.0, 'Bad': 78.43}, {'area': 'Area 6', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 6_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}]}, 'by_survey': {'top': {'exp': 95.0, 'area': 'Area 6'}, 'least': {'exp': 22.18, 'area': 'Area 2'}, 'responses': [{'area': 'Area 6', 'Excellent': 2, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 2, 'Exp Index': 95.0, 'Status': 'Active'}, {'area': 'Area 6_pct', 'Excellent': 100.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 3', 'Excellent': 96, 'Good': 14, 'Average': 10, 'Poor': 9, 'Bad': 13, 'Total Responses': 142, 'Exp Index': 77.08, 'Status': 'Active'}, {'area': 'Area 3_pct', 'Excellent': 67.61, 'Good': 9.86, 'Average': 7.04, 'Poor': 6.34, 'Bad': 9.15}, {'area': 'Area 1', 'Excellent': 215, 'Good': 273, 'Average': 43, 'Poor': 24, 'Bad': 51, 'Total Responses': 606, 'Exp Index': 71.22, 'Status': 'Active'}, {'area': 'Area 1_pct', 'Excellent': 35.48, 'Good': 45.05, 'Average': 7.1, 'Poor': 3.96, 'Bad': ...
# {'date': '2020-03-01', 'type': 'EI', 'general': {'total_devices': {'num': 10, 'active': 2}, 'active_surveys': {'num': 6, 'completed': 2}, 'rank': 24, 'total_resp_till_date': 44600, 'avg_exp_index': 54.43, 'avg_imp_index': -12.648362, 'all_responses': [{'resp': 'resp_no', 'Excellent': 1, 'Good': 1, 'Average': 1, 'Poor': 1, 'Bad': 0, 'Total Responses': 4, 'Exp Index': 61.25}, {'resp': 'resp_pct', 'Excellent': 25.0, 'Good': 25.0, 'Average': 25.0, 'Poor': 25.0, 'Bad': 0.0}]}, 'by_device': {'top': {'exp': 61.5, 'area': 'Area 1'}, 'least': {'exp': 61.0, 'area': 'Area 4'}, 'responses': [{'area': 'Area 1', 'Excellent': 1, 'Good': 0, 'Average': 0, 'Poor': 1, 'Bad': 0, 'Total Responses': 2, 'Exp Index': 61.5, 'Improvement Index': -23.84}, {'area': 'Area 1_pct', 'Excellent': 50.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 50.0, 'Bad': 0.0}, {'area': 'Area 4', 'Excellent': 0, 'Good': 1, 'Average': 1, 'Poor': 0, 'Bad': 0, 'Total Responses': 2, 'Exp Index': 61.0}, {'area': 'Area 4_pct', 'Excellent': 0.0, 'Good': 50.0, 'Average': 50.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 2', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 2_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 5', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 5_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 7', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 7_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 3', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 3_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 10', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 10_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 8', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 8_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 9', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 9_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 6', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 6_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}]}, 'by_survey': {'top': {'exp': 61.5, 'area': 'Area 1'}, 'least': {'exp': 0.0, 'area': 'Area 6'}, 'responses': [{'area': 'Area 1', 'Excellent': 1, 'Good': 0, 'Average': 0, 'Poor': 1, 'Bad': 0, 'Total Responses': 2, 'Exp Index': 61.5, 'Status': 'Active'}, {'area': 'Area 1_pct', 'Excellent': 50.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 50.0, 'Bad': 0.0}, {'area': 'Area 2', 'Excellent': 0, 'Good': 1, 'Average': 1, 'Poor': 0, 'Bad': 0, 'Total Responses': 2, 'Exp Index': 61.0, 'Status': 'Active'}, {'area': 'Area 2_pct', 'Excellent': 0.0, 'Good': 50.0, 'Average': 50.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 3', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0, 'Status': 'Active'}, {'area': 'Area 3_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 4', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0, 'Status': 'Active'}, {'area': 'Area 4_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 5', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0, 'Statu ...
# {'date': '2020-03-01', 'type': 'EI', 'general': {'total_devices': {'num': 10, 'active': 10}, 'active_surveys': {'num': 6, 'completed': 2}, 'rank': 10, 'total_resp_till_date': 278239, 'avg_exp_index': 87.01, 'avg_imp_index': 0.647975, 'all_responses': [{'resp': 'resp_no', 'Excellent': 285, 'Good': 73, 'Average': 39, 'Poor': 39, 'Bad': 15, 'Total Responses': 451, 'Exp Index': 78.6}, {'resp': 'resp_pct', 'Excellent': 63.19, 'Good': 16.19, 'Average': 8.65, 'Poor': 8.65, 'Bad': 3.33}]}, 'by_device': {'top': {'exp': 91.17, 'area': 'Area 4'}, 'least': {'exp': 67.7, 'area': 'Area 8'}, 'responses': [{'area': 'Area 4', 'Excellent': 15, 'Good': 3, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 18, 'Exp Index': 91.17, 'Improvement Index': 11.41}, {'area': 'Area 4_pct', 'Excellent': 83.33, 'Good': 16.67, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 1', 'Excellent': 11, 'Good': 3, 'Average': 2, 'Poor': 0, 'Bad': 0, 'Total Responses': 16, 'Exp Index': 85.06, 'Improvement Index': -3.34}, {'area': 'Area 1_pct', 'Excellent': 68.75, 'Good': 18.75, 'Average': 12.5, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 2', 'Excellent': 71, 'Good': 25, 'Average': 4, 'Poor': 5, 'Bad': 0, 'Total Responses': 105, 'Exp Index': 84.62, 'Improvement Index': 14.34}, {'area': 'Area 2_pct', 'Excellent': 67.62, 'Good': 23.81, 'Average': 3.81, 'Poor': 4.76, 'Bad': 0.0}, {'area': 'Area 3', 'Excellent': 83, 'Good': 9, 'Average': 4, 'Poor': 1, 'Bad': 7, 'Total Responses': 104, 'Exp Index': 84.58, 'Improvement Index': 4.39}, {'area': 'Area 3_pct', 'Excellent': 79.81, 'Good': 8.65, 'Average': 3.85, 'Poor': 0.96, 'Bad': 6.73}, {'area': 'Area 10', 'Excellent': 15, 'Good': 8, 'Average': 4, 'Poor': 3, 'Bad': 0, 'Total Responses': 30, 'Exp Index': 76.17, 'Improvement Index': 18.03}, {'area': 'Area 10_pct', 'Excellent': 50.0, 'Good': 26.67, 'Average': 13.33, 'Poor': 10.0, 'Bad': 0.0}, {'area': 'Area 5', 'Excellent': 52, 'Good': 18, 'Average': 15, 'Poor': 22, 'Bad': 0, 'Total Responses': 107, 'Exp Index': 71.05, 'Improvement Index': -4.5}, {'area': 'Area 5_pct', 'Excellent': 48.6, 'Good': 16.82, 'Average': 14.02, 'Poor': 20.56, 'Bad': 0.0}, {'area': 'Area 7', 'Excellent': 14, 'Good': 1, 'Average': 4, 'Poor': 3, 'Bad': 2, 'Total Responses': 24, 'Exp Index': 70.67, 'Improvement Index': 20.14}, {'area': 'Area 7_pct', 'Excellent': 58.33, 'Good': 4.17, 'Average': 16.67, 'Poor': 12.5, 'Bad': 8.33}, {'area': 'Area 8', 'Excellent': 24, 'Good': 6, 'Average': 6, 'Poor': 5, 'Bad': 6, 'Total Responses': 47, 'Exp Index': 67.7, 'Improvement Index': 17.43}, {'area': 'Area 8_pct', 'Excellent': 51.06, 'Good': 12.77, 'Average': 12.77, 'Poor': 10.64, 'Bad': 12.77}, {'area': 'Area 9', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 9_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 6', 'Excellent': 0, 'Good': 0, 'Average': 0, 'Poor': 0, 'Bad': 0, 'Total Responses': 0, 'Exp Index': 0.0}, {'area': 'Area 6_pct', 'Excellent': 0.0, 'Good': 0.0, 'Average': 0.0, 'Poor': 0.0, 'Bad': 0.0}]}, 'by_survey': {'top': {'exp': 85.06, 'area': 'Area 1'}, 'least': {'exp': 0.0, 'area': 'Area 6'}, 'responses': [{'area': 'Area 1', 'Excellent': 11, 'Good': 3, 'Average': 2, 'Poor': 0, 'Bad': 0, 'Total Responses': 16, 'Exp Index': 85.06, 'Status': 'Active', 'Survey Date': '29-08-18 to 31-12-21'}, {'area': 'Area 1_pct', 'Excellent': 68.75, 'Good': 18.75, 'Average': 12.5, 'Poor': 0.0, 'Bad': 0.0}, {'area': 'Area 2', 'Excellent': 71, 'Good': 25, 'Average': 4, 'Poor': 5, 'Bad': 0, 'Total Responses': 105, 'Exp Index': 84.62, 'Status': 'Active', 'Survey Date': '29-08-18 to 31-12-21'}, {'area': 'Area 2_pct', 'Excellent': 67.62, 'Good': 23.81, 'Average': 3.81, 'Poor': 4.76, 'Bad': 0.0}, {'area': 'Area 3', 'Excellent': 164, 'Good': 31, 'Average': 23, 'Poor': 26, 'Bad': 9, 'Total Responses': 253, 'Exp Index': 78.0, 'Status': 'Active', 'Survey Date': '29-08-18 to 31-12-21'}, {'area': 'Area 3_pct', 'Excellent ...
