# %%
import pandas as pd
import os
import numpy as np
import re
from datetime import datetime
from pymongo import MongoClient

# %%
def cleanNull(d):
    clean = {}   
    for k, v in d.items():
        if isinstance(v, dict):
            nested = cleanNull(v)
            if len(nested.keys()) > 0:
                clean[k] = nested
        elif v is not None:
            if isinstance(v,list):
                v = [v for v in v if str(v) !='nan']
                clean[k] = v
            else:
                clean[k] = v   
    return clean

# %%
arr = os.listdir('./excel')
file = [f for f in arr if f[-3:]=='xls']
### Loading sheets into DF ###
df = pd.read_excel('./excel/'+file[1],skiprows=[5,9,1], sheet_name=[0,1,2],header=None)
### Formatting ###
t = df[0].loc[3,[1,2]].str.extract('(\d*\s)',expand=False).astype(int)
    
### Formatting strings ###
for x in range(3):
    df[x].loc[3,[1,2]] = df[x].loc[3,[1,2]].str.extract('(\d*\s)',expand=False).astype(int)
    df[x].loc[6] = df[x].loc[6].str.extract('(\d*\.\d+|\d+)', expand=False).astype(float)  
    
### Extracting numbers from str ###
    for i in range(9,len(df[x]),2):
        df[x].loc[i] = df[x].loc[i].str.extract('(\d*\.\d+|\d+)', expand=False).astype(float) 
        
### Conversion from str to numeric ###    
    l = [2,5,6]
    for i in l:
        df[x].iloc[i,1:] = pd.to_numeric(df[x].iloc[i,1:], errors = 'coerce',downcast='float')
    for i in range(8,len(df[x].index)):
        df[x].iloc[i,1:8] = pd.to_numeric(df[x].iloc[i,1:8], errors = 'coerce',downcast='float')
        if(x==0):
            df[x].iloc[i,8] = pd.to_numeric(df[x].iloc[i,8], errors = 'coerce',downcast='float')      

### Extracting Date & type ###
st=df[0].iloc[0,0]
date = re.findall(r"\d{2}\s\w{3}\s\d{4}",st)
dates=str(datetime.strptime(date[0],'%d %b %Y').date())
s = df[0].iloc[1,3]
types = (re.findall(r"\s\w*\s",s))[0].strip()
    
### airport data ###
airport = df[0].iloc[1:4,:].copy()
airport.drop(airport.iloc[:, 4:6], inplace = True, axis = 1) 
header = airport.iloc[0]
airport = airport.iloc[1:]
airport.columns = header
airport_name = airport.iloc[0,0]

total_devices = {
    'num': airport['Total Devices'].iloc[0],
    'active': airport['Total Devices'].iloc[1]
}
active_surveys = {
    'num': airport['Active Surveys'].iloc[0],
    'completed': airport['Active Surveys'].iloc[1]
}

r = re.compile(".*Rank")
rank_name = list(filter(r.match, airport.columns))[0] 
rank = airport[rank_name].iloc[0]

total_resp_till_date = airport['Total Responses Till Date'].iloc[0]

exp_index_till_date = airport['Exp. Index Till Date'].iloc[0]

avg_imp_index = airport['Improvement Index'].iloc[0]

### all_responses ###
head = df[0].iloc[4,1:].dropna()
allResponses = df[0].iloc[5:7,1:].dropna(axis = 1, how = 'all')
allResponses.columns = head
all_resp = allResponses.to_dict('list')

### general data input ###
general = {
        'total_devices': total_devices,
        'active_surveys': active_surveys,
        'rank': rank,
        'total_resp_till_date': total_resp_till_date,
        'avg_exp_index': exp_index_till_date,
        'avg_imp_index': avg_imp_index,
        'all_responses': all_resp
    }

### data ###
data = {
    'date': dates,
    'type': types,
    'general': general
}

for i in range(3):
    bytype = df[i].iloc[8:].dropna(axis = 1, how = 'all')
    col_index = df[i].iloc[7,:].dropna()
    bytype.columns = col_index
    bytype.set_index(df[i].iloc[7,0],inplace = True)
    bytype.index = pd.Series(bytype.index).fillna(method='ffill')
    byType = bytype.groupby(df[i].iloc[7,0]).agg(lambda x: list(x))
    byType.columns = df[i].iloc[7,1:].dropna()
    byType.reset_index(inplace=True)
    byType.rename(columns={byType.columns[0]:'area'},inplace=True)
    resp = byType.to_dict('record')
    ### getting top and least areas ###
    air = df[0].iloc[1:4,:].copy()
    header = air.iloc[0]
    air = air.iloc[1:]
    air.columns = header

    r = re.compile("Top")
    top_name = list(filter(r.match, air.columns))[0]  
    tnum = air[top_name].iloc[0]
    tarea = air[top_name].iloc[1]
    
    r = re.compile("Least")
    least_name = list(filter(r.match, air.columns))[0]  
    lnum = air[least_name].iloc[0]
    larea = air[least_name].iloc[1]
    top = {
        'num': tnum,
        'area': tarea
    }
    least = {
        'num': lnum,
        'area': larea
    }
    by_name = (df[i].iloc[7,0]).replace(" ","_").lower()
    by_type = {
        'top': top,
        'least': least,
        'responses': resp
    }
    data.update({by_name: by_type})

# data = (cleanNull(data))
data
# Out:
# {'date': '2020-03-01',
#  'type': 'EI',
#  'general': {'date': '2020-03-01',
#   'type': 'EI',
#   'general': {'total_devices': {'num': 10.0, 'active': 2},
#    'active_surveys': {'num': 6.0, 'completed': 2},
#    'rank': 24.0,
#    'total_resp_till_date': 44600.0,
#    'avg_exp_index': 54.43000030517578,
#    'avg_imp_index': -12.648362159729004,
#    'all_responses': {'Excellent': [1.0, 25.0],
#     'Good': [1.0, 25.0],
#     'Average': [1.0, 25.0],
#     'Poor': [1.0, 25.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [4.0, nan],
#     'Exp. Index': [61.25, nan]}}},
#  'by_device': {'top': {'num': 61.5, 'area': 'Area 1'},
#   'least': {'num': 61.0, 'area': 'Area 4'},
#   'responses': [{'area': 'Area 1',
#     'Excellent': [1.0, 50.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [1.0, 50.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [2.0, nan],
#     'Exp. Index': [61.5, nan],
#     'Improvement Index': [-23.84, nan]},
#    {'area': 'Area 10',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 2',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 3',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 4',
#     'Excellent': [0.0, 0.0],
#     'Good': [1.0, 50.0],
#     'Average': [1.0, 50.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [2.0, nan],
#     'Exp. Index': [61.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 5',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 6',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 7',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 8',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]},
#    {'area': 'Area 9',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Improvement Index': [nan, nan]}]},
#  'by_survey': {'top': {'num': 61.5, 'area': 'Area 1'},
#   'least': {'num': 61.0, 'area': 'Area 4'},
#   'responses': [{'area': 'Area 1',
#     'Excellent': [1.0, 50.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [1.0, 50.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [2.0, nan],
#     'Exp. Index': [61.5, nan],
#     'Status': ['Active', nan]},
#    {'area': 'Area 2',
#     'Excellent': [0.0, 0.0],
#     'Good': [1.0, 50.0],
#     'Average': [1.0, 50.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [2.0, nan],
#     'Exp. Index': [61.0, nan],
#     'Status': ['Active', nan]},
#    {'area': 'Area 3',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Status': ['Active', nan]},
#    {'area': 'Area 4',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Status': ['Active', nan]},
#    {'area': 'Area 5',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Status': ['Active', nan]},
#    {'area': 'Area 6',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan],
#     'Status': ['Active', nan]}]},
#  'by_group': {'top': {'num': 61.5, 'area': 'Area 1'},
#   'least': {'num': 61.0, 'area': 'Area 4'},
#   'responses': [{'area': 'AAI Agartala',
#     'Excellent': [1.0, 25.0],
#     'Good': [1.0, 25.0],
#     'Average': [1.0, 25.0],
#     'Poor': [1.0, 25.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [4.0, nan],
#     'Exp. Index': [61.25, nan]},
#    {'area': 'Area 1',
#     'Excellent': [1.0, 50.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [1.0, 50.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [2.0, nan],
#     'Exp. Index': [61.5, nan]},
#    {'area': 'Area 2',
#     'Excellent': [0.0, 0.0],
#     'Good': [1.0, 50.0],
#     'Average': [1.0, 50.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [2.0, nan],
#     'Exp. Index': [61.0, nan]},
#    {'area': 'Area 3',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan]},
#    {'area': 'Area 4',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan]},
#    {'area': 'Area 5',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan]},
#    {'area': 'Area 6',
#     'Excellent': [0.0, 0.0],
#     'Good': [0.0, 0.0],
#     'Average': [0.0, 0.0],
#     'Poor': [0.0, 0.0],
#     'Bad': [0.0, 0.0],
#     'Total Responses': [0.0, nan],
#     'Exp. Index': [0.0, nan]}]}}
